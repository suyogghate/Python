# %%
hello = "Hello Jupyter"
print(hello)
# Out:
# Hello Jupyter

# %%
print(hello)
# Out:
# Hello Jupyter

# %%
name=input("Enter your name:")
print("Hi ", name)
# Out:
# Enter your name: rajesh
# Hi  rajesh

# %%
print("Hope to see you in the class")
# Out:
# Hope to see you in the class

# %% [markdown]
# # Below is a graph of diagonal line
# This is a bigger title

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,2,3,4])
plt.show()

# %% [markdown]
# # Welcome to my simple graph

# %%
plt.plot([1,2,3,4], [1,2,3,4])
plt.plot([1,8,4,4], [1,2,3,4])
plt.plot([6,4,9,4], [1,2,3,4])
plt.plot([8,2,7,4], [1,2,3,4])
plt.plot([3,2,8,1], [1,2,3,4])
plt.show()
